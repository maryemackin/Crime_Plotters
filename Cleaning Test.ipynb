# %%
# Dependencies
import pandas as pd
from pathlib import Path
from pprint import pprint

# %%
# reading the CSV and creating a dataframe from the information
original_crime_file = Path("offensesperori_final.csv")
og_crime_df = pd.read_csv(original_crime_file)
og_crime_df.head()
# Out:
#    Unnamed: 0  data_year  Aggravated Assault  \
# 0           0     2017.0               380.0
# 1           1     2018.0               442.0
# 2           2     2019.0               353.0
# 3           3     2020.0               387.0
# 4           4     2022.0               345.0
#
#    All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                               1428.0    6.0      50.0
# 1                               1394.0    7.0      71.0
# 2                               1163.0    2.0      40.0
# 3                                826.0    9.0      73.0
# 4                                800.0    5.0      27.0
#
#    Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                  0.0                12.0
# 1                                  0.0                 7.0
# 2                                  0.0                14.0
# 3                                  0.0                19.0
# 4                                  0.0                78.0
#
#    Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                        331.0                               1816.0  ...
# 1                        293.0                               1700.0  ...
# 2                        268.0                               1641.0  ...
# 3                        139.0                               1299.0  ...
# 4                        144.0                                745.0  ...
#
#    Rape  Robbery  Simple Assault  \
# 0  10.0     83.0           340.0
# 1   9.0     76.0           345.0
# 2   7.0     71.0           384.0
# 3  10.0     49.0           387.0
# 4   7.0     45.0           323.0
#
#    Stolen Property: Buying, Receiving, Possessing  Suspicion  Vagrancy  \
# 0                                           128.0        0.0       3.0
# 1                                           106.0        0.0       5.0
# 2                                            70.0        0.0       0.0
# 3                                           142.0        0.0       5.0
# 4                                           119.0        0.0       4.0
#
#    Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0       38.0                                125.0
# 1       59.0                                125.0
# 2       55.0                                146.0
# 3       52.0                                137.0
# 4       53.0                                236.0
#
#    Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                               24.0
# 1                                               32.0
# 2                                               20.0
# 3                                               27.0
# 4                                               13.0
#
#    ori_number
# 0   CA0010000
# 1   CA0010000
# 2   CA0010000
# 3   CA0010000
# 4   CA0010000
#
# [5 rows x 34 columns]

# %%
# use the starts with method to clean the dataframe to only contain California agencies
california_agencies = og_crime_df[og_crime_df['ori_number'].str.startswith('CA')]

california_agencies
# Out:
#       Unnamed: 0  data_year  Aggravated Assault  \
# 0              0     2017.0               380.0
# 1              1     2018.0               442.0
# 2              2     2019.0               353.0
# 3              3     2020.0               387.0
# 4              4     2022.0               345.0
# ...          ...        ...                 ...
# 3554           0     2019.0                 1.0
# 3555           1     2021.0                 3.0
# 3556           2     2022.0                 4.0
# 3557           0     2021.0                 2.0
# 3558           1     2022.0                 1.0
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                  1428.0    6.0      50.0
# 1                                  1394.0    7.0      71.0
# 2                                  1163.0    2.0      40.0
# 3                                   826.0    9.0      73.0
# 4                                   800.0    5.0      27.0
# ...                                   ...    ...       ...
# 3554                                  0.0    0.0       0.0
# 3555                                 16.0    0.0       1.0
# 3556                                 41.0    0.0       0.0
# 3557                                  9.0    0.0       0.0
# 3558                                 12.0    0.0       1.0
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                     0.0                12.0
# 1                                     0.0                 7.0
# 2                                     0.0                14.0
# 3                                     0.0                19.0
# 4                                     0.0                78.0
# ...                                   ...                 ...
# 3554                                  0.0                 0.0
# 3555                                  0.0                 2.0
# 3556                                  0.0                 1.0
# 3557                                  0.0                 0.0
# 3558                                  0.0                 0.0
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                           331.0                               1816.0  ...
# 1                           293.0                               1700.0  ...
# 2                           268.0                               1641.0  ...
# 3                           139.0                               1299.0  ...
# 4                           144.0                                745.0  ...
# ...                           ...                                  ...  ...
# 3554                          0.0                                  0.0  ...
# 3555                          1.0                                121.0  ...
# 3556                          3.0                                 73.0  ...
# 3557                          6.0                                 25.0  ...
# 3558                         16.0                                 47.0  ...
#
#       Rape  Robbery  Simple Assault  \
# 0     10.0     83.0           340.0
# 1      9.0     76.0           345.0
# 2      7.0     71.0           384.0
# 3     10.0     49.0           387.0
# 4      7.0     45.0           323.0
# ...    ...      ...             ...
# 3554   0.0      0.0             0.0
# 3555   0.0      0.0             6.0
# 3556   0.0      1.0             6.0
# 3557   0.0      0.0             5.0
# 3558   0.0      0.0            10.0
#
#       Stolen Property: Buying, Receiving, Possessing  Suspicion  Vagrancy  \
# 0                                              128.0        0.0       3.0
# 1                                              106.0        0.0       5.0
# 2                                               70.0        0.0       0.0
# 3                                              142.0        0.0       5.0
# 4                                              119.0        0.0       4.0
# ...                                              ...        ...       ...
# 3554                                             0.0        0.0       0.0
# 3555                                             1.0        0.0       0.0
# 3556                                             2.0        0.0       0.0
# 3557                                             0.0        0.0       0.0
# 3558                                             0.0        0.0       0.0
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0          38.0                                125.0
# 1          59.0                                125.0
# 2          55.0                                146.0
# 3          52.0                                137.0
# 4          53.0                                236.0
# ...         ...                                  ...
# 3554        0.0                                  1.0
# 3555        3.0                                  1.0
# 3556        0.0                                  3.0
# 3557        1.0                                  0.0
# 3558        1.0                                  1.0
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                  24.0
# 1                                                  32.0
# 2                                                  20.0
# 3                                                  27.0
# 4                                                  13.0
# ...                                                 ...
# 3554                                                0.0
# 3555                                                0.0
# 3556                                                0.0
# 3557                                                0.0
# 3558                                                0.0
#
#       ori_number
# 0      CA0010000
# 1      CA0010000
# 2      CA0010000
# 3      CA0010000
# 4      CA0010000
# ...          ...
# 3554   CADIT1400
# 3555   CADIT1400
# 3556   CADIT1400
# 3557   CADIT1600
# 3558   CADIT1600
#
# [3559 rows x 34 columns]

# %%
# reads in files that contain agency names
ca_agency_names = Path("orinum_agencyname.csv")
ca_names = pd.read_csv(ca_agency_names)

#change the name of the ORI column to match our original dataframe
ca_names = ca_names.rename(columns={'ORI':'ori_number'})
ca_names
# Out:
#     ori_number                                  AGENCY_NAME
# 0    CA0010000          Alameda County Sheriff's Department
# 1    CA0010100                    Alameda Police Department
# 2    CA001013A                                ALAMEDA CO DA
# 3    CA001013G         Alameda County Probation Department
# 4    CA0010200                     Albany Police Department
# ..         ...                                          ...
# 563  CA0580100                 Marysville Police Department
# 564  CA058013A                    YUBA CO DISTRICT ATTORNEY
# 565  CA058013G            Yuba County Probation Department
# 566  CA0580200                  Wheatland Police Department
# 567  UR0569901  Ventura Community College Police Department
#
# [568 rows x 2 columns]

# %%
# completes a right merge to add the agency names to the california
merge_1 = pd.merge(california_agencies, ca_names, how = 'right', on='ori_number')
merge_1
# Out:
#       Unnamed: 0  data_year  Aggravated Assault  \
# 0            0.0     2017.0               380.0
# 1            1.0     2018.0               442.0
# 2            2.0     2019.0               353.0
# 3            3.0     2020.0               387.0
# 4            4.0     2022.0               345.0
# ...          ...        ...                 ...
# 2433         1.0     2018.0                 6.0
# 2434         2.0     2019.0                11.0
# 2435         3.0     2020.0                 9.0
# 2436         4.0     2022.0                13.0
# 2437         NaN        NaN                 NaN
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                  1428.0    6.0      50.0
# 1                                  1394.0    7.0      71.0
# 2                                  1163.0    2.0      40.0
# 3                                   826.0    9.0      73.0
# 4                                   800.0    5.0      27.0
# ...                                   ...    ...       ...
# 2433                                  6.0    1.0       0.0
# 2434                                  8.0    0.0       2.0
# 2435                                 15.0    0.0       1.0
# 2436                                  7.0    0.0       1.0
# 2437                                  NaN    NaN       NaN
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                     0.0                12.0
# 1                                     0.0                 7.0
# 2                                     0.0                14.0
# 3                                     0.0                19.0
# 4                                     0.0                78.0
# ...                                   ...                 ...
# 2433                                  0.0                 1.0
# 2434                                  0.0                 0.0
# 2435                                  0.0                 0.0
# 2436                                  0.0                 0.0
# 2437                                  NaN                 NaN
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                           331.0                               1816.0  ...
# 1                           293.0                               1700.0  ...
# 2                           268.0                               1641.0  ...
# 3                           139.0                               1299.0  ...
# 4                           144.0                                745.0  ...
# ...                           ...                                  ...  ...
# 2433                         65.0                                 16.0  ...
# 2434                         46.0                                 27.0  ...
# 2435                         44.0                                151.0  ...
# 2436                         36.0                                 31.0  ...
# 2437                          NaN                                  NaN  ...
#
#       Robbery  Simple Assault  Stolen Property: Buying, Receiving, Possessing  \
# 0        83.0           340.0                                           128.0
# 1        76.0           345.0                                           106.0
# 2        71.0           384.0                                            70.0
# 3        49.0           387.0                                           142.0
# 4        45.0           323.0                                           119.0
# ...       ...             ...                                             ...
# 2433      0.0            11.0                                             4.0
# 2434      0.0            10.0                                             5.0
# 2435      1.0             9.0                                             2.0
# 2436      0.0            10.0                                             1.0
# 2437      NaN             NaN                                             NaN
#
#       Suspicion  Vagrancy  Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0           0.0       3.0       38.0                                125.0
# 1           0.0       5.0       59.0                                125.0
# 2           0.0       0.0       55.0                                146.0
# 3           0.0       5.0       52.0                                137.0
# 4           0.0       4.0       53.0                                236.0
# ...         ...       ...        ...                                  ...
# 2433        0.0       0.0        0.0                                  0.0
# 2434        0.0       0.0        1.0                                  2.0
# 2435        0.0       0.0        3.0                                 12.0
# 2436        0.0       0.0        1.0                                  5.0
# 2437        NaN       NaN        NaN                                  NaN
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                  24.0
# 1                                                  32.0
# 2                                                  20.0
# 3                                                  27.0
# 4                                                  13.0
# ...                                                 ...
# 2433                                                3.0
# 2434                                                1.0
# 2435                                                2.0
# 2436                                                3.0
# 2437                                                NaN
#
#       ori_number                                  AGENCY_NAME
# 0      CA0010000          Alameda County Sheriff's Department
# 1      CA0010000          Alameda County Sheriff's Department
# 2      CA0010000          Alameda County Sheriff's Department
# 3      CA0010000          Alameda County Sheriff's Department
# 4      CA0010000          Alameda County Sheriff's Department
# ...          ...                                          ...
# 2433   CA0580200                  Wheatland Police Department
# 2434   CA0580200                  Wheatland Police Department
# 2435   CA0580200                  Wheatland Police Department
# 2436   CA0580200                  Wheatland Police Department
# 2437   UR0569901  Ventura Community College Police Department
#
# [2438 rows x 35 columns]

# %%
#reads in new csv that contains county codes and county names
ca_counties = Path("state_agencies.csv")
county_names = pd.read_csv(ca_counties)

#filters for only the California information as the data frame includes New York and Illinois as well 
ca_county_names = county_names.loc[county_names["state_abbr"] == "CA"]

#delete columns that don't need to be put into merged dataframe
del ca_county_names['Unnamed: 0']
del ca_county_names['state_abbr']
del ca_county_names['agency_name']

#changes the name of the column being merged on to match existing df
ca_county_names = ca_county_names.rename(columns={'ori':'ori_number'})

ca_county_names
# Out:
#      agency_id agency_type_name ori_number    county_name   latitude  \
# 0          937           County  CA0010000        ALAMEDA  37.802000
# 1          938             City  CA0010100        ALAMEDA  37.766888
# 2          939             City  CA0010200        ALAMEDA  37.887703
# 3          940             City  CA0010300        ALAMEDA  37.870537
# 4          941             City  CA0010400        ALAMEDA  37.648134
# ..         ...              ...        ...            ...        ...
# 831       1825           Tribal  CADIT0800  NOT SPECIFIED  40.706673
# 832      25264           Tribal  CADIT0900  NOT SPECIFIED        NaN
# 833      25313           Tribal  CADIT1100  NOT SPECIFIED        NaN
# 834      30614           Tribal  CADIT1400  NOT SPECIFIED        NaN
# 835      32175           Tribal  CADIT1600  NOT SPECIFIED        NaN
#
#       longitude
# 0   -122.262360
# 1   -122.242730
# 2   -122.298250
# 3   -122.272980
# 4   -121.913291
# ..          ...
# 831 -123.925818
# 832         NaN
# 833         NaN
# 834         NaN
# 835         NaN
#
# [836 rows x 6 columns]

# %%
#merge ca_county_names df into the california dataframe to now add the county-level information
#Using an outer merge to capture all of the information in both dataframes
california_crime_counties = pd.merge(merge_1, ca_county_names, how='outer', on='ori_number')



california_crime_counties
# Out:
#       Unnamed: 0  data_year  Aggravated Assault  \
# 0            0.0     2017.0               380.0
# 1            1.0     2018.0               442.0
# 2            2.0     2019.0               353.0
# 3            3.0     2020.0               387.0
# 4            4.0     2022.0               345.0
# ...          ...        ...                 ...
# 2825         NaN        NaN                 NaN
# 2826         NaN        NaN                 NaN
# 2827         NaN        NaN                 NaN
# 2828         NaN        NaN                 NaN
# 2829         NaN        NaN                 NaN
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                  1428.0    6.0      50.0
# 1                                  1394.0    7.0      71.0
# 2                                  1163.0    2.0      40.0
# 3                                   826.0    9.0      73.0
# 4                                   800.0    5.0      27.0
# ...                                   ...    ...       ...
# 2825                                  NaN    NaN       NaN
# 2826                                  NaN    NaN       NaN
# 2827                                  NaN    NaN       NaN
# 2828                                  NaN    NaN       NaN
# 2829                                  NaN    NaN       NaN
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                     0.0                12.0
# 1                                     0.0                 7.0
# 2                                     0.0                14.0
# 3                                     0.0                19.0
# 4                                     0.0                78.0
# ...                                   ...                 ...
# 2825                                  NaN                 NaN
# 2826                                  NaN                 NaN
# 2827                                  NaN                 NaN
# 2828                                  NaN                 NaN
# 2829                                  NaN                 NaN
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                           331.0                               1816.0  ...
# 1                           293.0                               1700.0  ...
# 2                           268.0                               1641.0  ...
# 3                           139.0                               1299.0  ...
# 4                           144.0                                745.0  ...
# ...                           ...                                  ...  ...
# 2825                          NaN                                  NaN  ...
# 2826                          NaN                                  NaN  ...
# 2827                          NaN                                  NaN  ...
# 2828                          NaN                                  NaN  ...
# 2829                          NaN                                  NaN  ...
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0          38.0                                125.0
# 1          59.0                                125.0
# 2          55.0                                146.0
# 3          52.0                                137.0
# 4          53.0                                236.0
# ...         ...                                  ...
# 2825        NaN                                  NaN
# 2826        NaN                                  NaN
# 2827        NaN                                  NaN
# 2828        NaN                                  NaN
# 2829        NaN                                  NaN
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                  24.0
# 1                                                  32.0
# 2                                                  20.0
# 3                                                  27.0
# 4                                                  13.0
# ...                                                 ...
# 2825                                                NaN
# 2826                                                NaN
# 2827                                                NaN
# 2828                                                NaN
# 2829                                                NaN
#
#       ori_number                          AGENCY_NAME  agency_id  \
# 0      CA0010000  Alameda County Sheriff's Department      937.0
# 1      CA0010000  Alameda County Sheriff's Department      937.0
# 2      CA0010000  Alameda County Sheriff's Department      937.0
# 3      CA0010000  Alameda County Sheriff's Department      937.0
# 4      CA0010000  Alameda County Sheriff's Department      937.0
# ...          ...                                  ...        ...
# 2825   CADIT0800                                  NaN     1825.0
# 2826   CADIT0900                                  NaN    25264.0
# 2827   CADIT1100                                  NaN    25313.0
# 2828   CADIT1400                                  NaN    30614.0
# 2829   CADIT1600                                  NaN    32175.0
#
#       agency_type_name    county_name   latitude   longitude
# 0               County        ALAMEDA  37.802000 -122.262360
# 1               County        ALAMEDA  37.802000 -122.262360
# 2               County        ALAMEDA  37.802000 -122.262360
# 3               County        ALAMEDA  37.802000 -122.262360
# 4               County        ALAMEDA  37.802000 -122.262360
# ...                ...            ...        ...         ...
# 2825            Tribal  NOT SPECIFIED  40.706673 -123.925818
# 2826            Tribal  NOT SPECIFIED        NaN         NaN
# 2827            Tribal  NOT SPECIFIED        NaN         NaN
# 2828            Tribal  NOT SPECIFIED        NaN         NaN
# 2829            Tribal  NOT SPECIFIED        NaN         NaN
#
# [2830 rows x 40 columns]

# %%
#checking counts
california_crime_counties.count()

#dropping all rows with NaN values
california_crime_counties.dropna(inplace=True)

# %%
#convert the data year and agency id columns to strings for style purposes

# Convert 'data_year' and 'agency_id' columns to integers
california_crime_counties['data_year'] = california_crime_counties['data_year'].astype(int)
california_crime_counties['agency_id'] = california_crime_counties['agency_id'].astype(int)

# Convert integers to strings
california_crime_counties['data_year'] = california_crime_counties['data_year'].astype(str)
california_crime_counties['agency_id'] = california_crime_counties['agency_id'].astype(str)

california_crime_counties
# Out:
#       Unnamed: 0 data_year  Aggravated Assault  \
# 0            0.0      2017               380.0
# 1            1.0      2018               442.0
# 2            2.0      2019               353.0
# 3            3.0      2020               387.0
# 4            4.0      2022               345.0
# ...          ...       ...                 ...
# 2432         0.0      2017                13.0
# 2433         1.0      2018                 6.0
# 2434         2.0      2019                11.0
# 2435         3.0      2020                 9.0
# 2436         4.0      2022                13.0
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                  1428.0    6.0      50.0
# 1                                  1394.0    7.0      71.0
# 2                                  1163.0    2.0      40.0
# 3                                   826.0    9.0      73.0
# 4                                   800.0    5.0      27.0
# ...                                   ...    ...       ...
# 2432                                  9.0    2.0       1.0
# 2433                                  6.0    1.0       0.0
# 2434                                  8.0    0.0       2.0
# 2435                                 15.0    0.0       1.0
# 2436                                  7.0    0.0       1.0
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                     0.0                12.0
# 1                                     0.0                 7.0
# 2                                     0.0                14.0
# 3                                     0.0                19.0
# 4                                     0.0                78.0
# ...                                   ...                 ...
# 2432                                  0.0                 1.0
# 2433                                  0.0                 1.0
# 2434                                  0.0                 0.0
# 2435                                  0.0                 0.0
# 2436                                  0.0                 0.0
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                           331.0                               1816.0  ...
# 1                           293.0                               1700.0  ...
# 2                           268.0                               1641.0  ...
# 3                           139.0                               1299.0  ...
# 4                           144.0                                745.0  ...
# ...                           ...                                  ...  ...
# 2432                         56.0                                 16.0  ...
# 2433                         65.0                                 16.0  ...
# 2434                         46.0                                 27.0  ...
# 2435                         44.0                                151.0  ...
# 2436                         36.0                                 31.0  ...
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0          38.0                                125.0
# 1          59.0                                125.0
# 2          55.0                                146.0
# 3          52.0                                137.0
# 4          53.0                                236.0
# ...         ...                                  ...
# 2432        0.0                                  1.0
# 2433        0.0                                  0.0
# 2434        1.0                                  2.0
# 2435        3.0                                 12.0
# 2436        1.0                                  5.0
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                  24.0
# 1                                                  32.0
# 2                                                  20.0
# 3                                                  27.0
# 4                                                  13.0
# ...                                                 ...
# 2432                                                3.0
# 2433                                                3.0
# 2434                                                1.0
# 2435                                                2.0
# 2436                                                3.0
#
#       ori_number                          AGENCY_NAME  agency_id  \
# 0      CA0010000  Alameda County Sheriff's Department        937
# 1      CA0010000  Alameda County Sheriff's Department        937
# 2      CA0010000  Alameda County Sheriff's Department        937
# 3      CA0010000  Alameda County Sheriff's Department        937
# 4      CA0010000  Alameda County Sheriff's Department        937
# ...          ...                                  ...        ...
# 2432   CA0580200          Wheatland Police Department       1818
# 2433   CA0580200          Wheatland Police Department       1818
# 2434   CA0580200          Wheatland Police Department       1818
# 2435   CA0580200          Wheatland Police Department       1818
# 2436   CA0580200          Wheatland Police Department       1818
#
#       agency_type_name  county_name   latitude  longitude
# 0               County      ALAMEDA  37.802000 -122.26236
# 1               County      ALAMEDA  37.802000 -122.26236
# 2               County      ALAMEDA  37.802000 -122.26236
# 3               County      ALAMEDA  37.802000 -122.26236
# 4               County      ALAMEDA  37.802000 -122.26236
# ...                ...          ...        ...        ...
# 2432              City         YUBA  39.270026 -121.34428
# 2433              City         YUBA  39.270026 -121.34428
# 2434              City         YUBA  39.270026 -121.34428
# 2435              City         YUBA  39.270026 -121.34428
# 2436              City         YUBA  39.270026 -121.34428
#
# [2286 rows x 40 columns]

# %%
#checking types
california_crime_counties.dtypes
# Out:
# Unnamed: 0                                                              float64
# data_year                                                                object
# Aggravated Assault                                                      float64
# All Other Offenses (Except Traffic)                                     float64
# Arson                                                                   float64
# Burglary                                                                float64
# Curfew and Loitering Law Violations                                     float64
# Disorderly Conduct                                                      float64
# Driving Under the Influence                                             float64
# Drug Abuse Violations - Grand Total                                     float64
# Drunkenness                                                             float64
# Embezzlement                                                            float64
# Forgery and Counterfeiting                                              float64
# Fraud                                                                   float64
# Gambling - Total                                                        float64
# Human Trafficking - Commercial Sex Acts                                 float64
# Human Trafficking - Involuntary Servitude                               float64
# Larceny - Theft                                                         float64
# Liquor Laws                                                             float64
# Manslaughter by Negligence                                              float64
# Motor Vehicle Theft                                                     float64
# Murder and Nonnegligent Manslaughter                                    float64
# Offenses Against the Family and Children                                float64
# Prostitution and Commercialized Vice                                    float64
# Rape                                                                    float64
# Robbery                                                                 float64
# Simple Assault                                                          float64
# Stolen Property: Buying, Receiving, Possessing                          float64
# Suspicion                                                               float64
# Vagrancy                                                                float64
# Vandalism                                                               float64
# Weapons: Carrying, Possessing, Etc.                                     float64
# Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)    float64
# ori_number                                                               object
# AGENCY_NAME                                                              object
# agency_id                                                                object
# agency_type_name                                                         object
# county_name                                                              object
# latitude                                                                float64
# longitude                                                               float64
# dtype: object

# %%
# set the new types for each column
new_types = {'Aggravated Assault': int,
             'All Other Offenses (Except Traffic)': int,
             'Arson': int,
             'Burglary': int,
             'Curfew and Loitering Law Violations': int,
             'Disorderly Conduct': int,
             'Driving Under the Influence': int,
             'Drug Abuse Violations - Grand Total': int,
             'Drunkenness': int,
             'Embezzlement': int,
             'Forgery and Counterfeiting': int,
             'Fraud': int,
             'Gambling - Total': int,
             'Human Trafficking - Commercial Sex Acts': int,
             'Human Trafficking - Involuntary Servitude': int,
             'Larceny - Theft': int,
             'Liquor Laws': int,
             'Manslaughter by Negligence': int,
             'Motor Vehicle Theft': int,
             'Murder and Nonnegligent Manslaughter': int,
             'Offenses Against the Family and Children': int,
             'Prostitution and Commercialized Vice': int,
             'Rape': int,
             'Robbery': int,
             'Simple Assault': int,
             'Stolen Property: Buying, Receiving, Possessing': int,
             'Suspicion': int,
             'Vagrancy': int,
             'Vandalism': int,
             'Weapons: Carrying, Possessing, Etc.': int,
             'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)': int
          }
#using the dictionaries to set new types
california_crime_counties = california_crime_counties.astype(new_types)
#california_crime_counties['data_year'] = california_crime_counties['data_year'].astype(str)
california_crime_counties
# Out:
#       Unnamed: 0 data_year  Aggravated Assault  \
# 0            0.0      2017                 380
# 1            1.0      2018                 442
# 2            2.0      2019                 353
# 3            3.0      2020                 387
# 4            4.0      2022                 345
# ...          ...       ...                 ...
# 2432         0.0      2017                  13
# 2433         1.0      2018                   6
# 2434         2.0      2019                  11
# 2435         3.0      2020                   9
# 2436         4.0      2022                  13
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                    1428      6        50
# 1                                    1394      7        71
# 2                                    1163      2        40
# 3                                     826      9        73
# 4                                     800      5        27
# ...                                   ...    ...       ...
# 2432                                    9      2         1
# 2433                                    6      1         0
# 2434                                    8      0         2
# 2435                                   15      0         1
# 2436                                    7      0         1
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                       0                  12
# 1                                       0                   7
# 2                                       0                  14
# 3                                       0                  19
# 4                                       0                  78
# ...                                   ...                 ...
# 2432                                    0                   1
# 2433                                    0                   1
# 2434                                    0                   0
# 2435                                    0                   0
# 2436                                    0                   0
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                             331                                 1816  ...
# 1                             293                                 1700  ...
# 2                             268                                 1641  ...
# 3                             139                                 1299  ...
# 4                             144                                  745  ...
# ...                           ...                                  ...  ...
# 2432                           56                                   16  ...
# 2433                           65                                   16  ...
# 2434                           46                                   27  ...
# 2435                           44                                  151  ...
# 2436                           36                                   31  ...
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0            38                                  125
# 1            59                                  125
# 2            55                                  146
# 3            52                                  137
# 4            53                                  236
# ...         ...                                  ...
# 2432          0                                    1
# 2433          0                                    0
# 2434          1                                    2
# 2435          3                                   12
# 2436          1                                    5
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                    24
# 1                                                    32
# 2                                                    20
# 3                                                    27
# 4                                                    13
# ...                                                 ...
# 2432                                                  3
# 2433                                                  3
# 2434                                                  1
# 2435                                                  2
# 2436                                                  3
#
#       ori_number                          AGENCY_NAME  agency_id  \
# 0      CA0010000  Alameda County Sheriff's Department        937
# 1      CA0010000  Alameda County Sheriff's Department        937
# 2      CA0010000  Alameda County Sheriff's Department        937
# 3      CA0010000  Alameda County Sheriff's Department        937
# 4      CA0010000  Alameda County Sheriff's Department        937
# ...          ...                                  ...        ...
# 2432   CA0580200          Wheatland Police Department       1818
# 2433   CA0580200          Wheatland Police Department       1818
# 2434   CA0580200          Wheatland Police Department       1818
# 2435   CA0580200          Wheatland Police Department       1818
# 2436   CA0580200          Wheatland Police Department       1818
#
#       agency_type_name  county_name   latitude  longitude
# 0               County      ALAMEDA  37.802000 -122.26236
# 1               County      ALAMEDA  37.802000 -122.26236
# 2               County      ALAMEDA  37.802000 -122.26236
# 3               County      ALAMEDA  37.802000 -122.26236
# 4               County      ALAMEDA  37.802000 -122.26236
# ...                ...          ...        ...        ...
# 2432              City         YUBA  39.270026 -121.34428
# 2433              City         YUBA  39.270026 -121.34428
# 2434              City         YUBA  39.270026 -121.34428
# 2435              City         YUBA  39.270026 -121.34428
# 2436              City         YUBA  39.270026 -121.34428
#
# [2286 rows x 40 columns]

# %%
#county level with all data
#create a new dataframe from a copy of the california_crime_counties dataframe
#county_full = california_crime_counties.copy()

#aggregate by crime types
county_full =  california_crime_counties.groupby(['county_name','data_year']).agg({
            'Aggravated Assault': 'sum',
             'All Other Offenses (Except Traffic)': 'sum',
             'Arson': 'sum',
             'Burglary': 'sum',
             'Curfew and Loitering Law Violations': 'sum',
             'Disorderly Conduct': 'sum',
             'Driving Under the Influence': 'sum',
             'Drug Abuse Violations - Grand Total': 'sum',
             'Drunkenness': 'sum',
             'Embezzlement': 'sum',
             'Forgery and Counterfeiting': 'sum',
             'Fraud': 'sum',
             'Gambling - Total': 'sum',
             'Human Trafficking - Commercial Sex Acts': 'sum',
             'Human Trafficking - Involuntary Servitude': 'sum',
             'Larceny - Theft': 'sum',
             'Liquor Laws': 'sum',
             'Manslaughter by Negligence': 'sum',
             'Motor Vehicle Theft': 'sum',
             'Murder and Nonnegligent Manslaughter': 'sum',
             'Offenses Against the Family and Children': 'sum',
             'Prostitution and Commercialized Vice': 'sum',
             'Rape': 'sum',
             'Robbery': 'sum',
             'Simple Assault': 'sum',
             'Stolen Property: Buying, Receiving, Possessing': 'sum',
             'Suspicion': 'sum',
             'Vagrancy': 'sum',
             'Vandalism': 'sum',
             'Weapons: Carrying, Possessing, Etc.': 'sum',
             'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)': 'sum'
})

# Calculate the count of unique agencies for each county and year
unique_agency_count_1 = california_crime_counties.groupby(['county_name', 'data_year'])['AGENCY_NAME'].nunique().reset_index()

# # Merge the unique agency count with county_level_data
county_full = county_full.merge(unique_agency_count_1, on=['county_name', 'data_year'], how='left')
county_full.rename(columns={'AGENCY_NAME': 'agency_count'}, inplace=True)

#create a csv file from the dataframe
county_full.to_csv('Output/county_level_including_all_agencies_and_available_years.csv')

# %%
#create a dataframe at the agency level with all years and all agencies
agency_level_full = california_crime_counties.groupby(['AGENCY_NAME','data_year']).agg({
    'Aggravated Assault': 'sum',
             'All Other Offenses (Except Traffic)': 'sum',
             'Arson': 'sum',
             'Burglary': 'sum',
             'Curfew and Loitering Law Violations': 'sum',
             'Disorderly Conduct': 'sum',
             'Driving Under the Influence': 'sum',
             'Drug Abuse Violations - Grand Total': 'sum',
             'Drunkenness': 'sum',
             'Embezzlement': 'sum',
             'Forgery and Counterfeiting': 'sum',
             'Fraud': 'sum',
             'Gambling - Total': 'sum',
             'Human Trafficking - Commercial Sex Acts': 'sum',
             'Human Trafficking - Involuntary Servitude': 'sum',
             'Larceny - Theft': 'sum',
             'Liquor Laws': 'sum',
             'Manslaughter by Negligence': 'sum',
             'Motor Vehicle Theft': 'sum',
             'Murder and Nonnegligent Manslaughter': 'sum',
             'Offenses Against the Family and Children': 'sum',
             'Prostitution and Commercialized Vice': 'sum',
             'Rape': 'sum',
             'Robbery': 'sum',
             'Simple Assault': 'sum',
             'Stolen Property: Buying, Receiving, Possessing': 'sum',
             'Suspicion': 'sum',
             'Vagrancy': 'sum',
             'Vandalism': 'sum',
             'Weapons: Carrying, Possessing, Etc.': 'sum',
             'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)': 'sum'
})

#create a csv file from the dataframe
agency_level_full.to_csv('Output/agency_level_including_all_agencies_and_available_years.csv')

# %%
#create a dataframe with the consolidated crime categories
#copy the dataframe
consolidated_crime_full_counties = california_crime_counties.copy()

#these are the crimes that should be mapped to the crimes against persons category
consolidated_crime_full_counties["Crimes Against Persons"] = consolidated_crime_full_counties["Aggravated Assault"] + consolidated_crime_full_counties["Human Trafficking - Commercial Sex Acts"] + consolidated_crime_full_counties["Human Trafficking - Involuntary Servitude"] + consolidated_crime_full_counties["Manslaughter by Negligence"] + consolidated_crime_full_counties["Murder and Nonnegligent Manslaughter"] + consolidated_crime_full_counties["Rape"] + consolidated_crime_full_counties["Simple Assault"] + consolidated_crime_full_counties["Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)"]

#these are the crimes that should be mapped to the crimes against society category
consolidated_crime_full_counties["Crimes Against Society"] = consolidated_crime_full_counties["Curfew and Loitering Law Violations"] + consolidated_crime_full_counties["Disorderly Conduct"] + consolidated_crime_full_counties["Driving Under the Influence"] + consolidated_crime_full_counties["Drug Abuse Violations - Grand Total"] + consolidated_crime_full_counties["Drunkenness"] + consolidated_crime_full_counties["Gambling - Total"] + consolidated_crime_full_counties["Liquor Laws"] + consolidated_crime_full_counties["Offenses Against the Family and Children"] + consolidated_crime_full_counties["Prostitution and Commercialized Vice"]+ consolidated_crime_full_counties["Vagrancy"]

#these are the crimes that should be mapped to the crimes against property category
consolidated_crime_full_counties["Crimes Against Property"] = consolidated_crime_full_counties["Arson"] + consolidated_crime_full_counties["Burglary"] + consolidated_crime_full_counties["Embezzlement"] + consolidated_crime_full_counties["Forgery and Counterfeiting"] + consolidated_crime_full_counties["Fraud"] + consolidated_crime_full_counties["Larceny - Theft"] + consolidated_crime_full_counties["Motor Vehicle Theft"] + consolidated_crime_full_counties["Robbery"]+ consolidated_crime_full_counties["Stolen Property: Buying, Receiving, Possessing"] + consolidated_crime_full_counties["Vandalism"]+ consolidated_crime_full_counties["Weapons: Carrying, Possessing, Etc."]


#create a list of columns to remove
columns_to_drop_1 = [
    'Unnamed: 0','Aggravated Assault', 'Arson', 'Burglary',
       'Curfew and Loitering Law Violations', 'Disorderly Conduct',
       'Driving Under the Influence', 'Drug Abuse Violations - Grand Total',
       'Drunkenness', 'Embezzlement', 'Forgery and Counterfeiting', 'Fraud',
       'Gambling - Total', 'Human Trafficking - Commercial Sex Acts',
       'Human Trafficking - Involuntary Servitude', 'Larceny - Theft',
       'Liquor Laws', 'Manslaughter by Negligence', 'Motor Vehicle Theft',
       'Murder and Nonnegligent Manslaughter',
       'Offenses Against the Family and Children',
       'Prostitution and Commercialized Vice', 'Rape', 'Robbery',
       'Simple Assault', 'Stolen Property: Buying, Receiving, Possessing', 'Vagrancy', 'Vandalism',
       'Weapons: Carrying, Possessing, Etc.',
       'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)' 
]
#deletes columns we no longer need
consolidated_crime_full_counties.drop(columns=columns_to_drop_1, inplace=True)

#reorder the columns in the dataframe
new_order_1 = ["data_year",
             "county_name",
             "AGENCY_NAME",
             "agency_id",
             "Crimes Against Persons",
             "Crimes Against Society",
             "Crimes Against Property",
             "All Other Offenses (Except Traffic)",
             "Suspicion",
             "latitude",
             "longitude",
             "ori_number",
             "agency_type_name",
            ]
#changes the order of the dataframe
consolidated_crime_full_counties = consolidated_crime_full_counties.reindex(columns=new_order_1)
consolidated_crime_full_counties_2 = consolidated_crime_full_counties

#organizes the dataframe to be grouped by county
consolidated_crime_full_counties = consolidated_crime_full_counties.groupby(['county_name','data_year']).agg({
    'Crimes Against Persons': 'sum',
             'Crimes Against Society': 'sum',
             'Crimes Against Property': 'sum',
})


consolidated_crime_full_counties.to_csv('Output/county_level_consolidated_all_agencies_all_available_years.csv')

# %%
#creates a dataframe of the consolidated crime categories at the agency level
#organizes the dataframe to be grouped by county

consolidated_crime_full_agencies = consolidated_crime_full_counties_2.groupby(['AGENCY_NAME','data_year']).agg({
    'Crimes Against Persons': 'sum',
             'Crimes Against Society': 'sum',
             'Crimes Against Property': 'sum',
})

consolidated_crime_full_agencies.to_csv('Output/agency_level_consolidated_all_agencies_all_available_years.csv')

# %%
#this snippet filters the data for agencies that have data for all six years
#to keep this consistent, it makes the most sense to only include agencies that have data for all years
#otherwise, our findings would misrepresent the realities for years with missing information

all_years_included = california_crime_counties.loc[california_crime_counties["Unnamed: 0"] == 5.0]
all_years_included
# Out:
#       Unnamed: 0 data_year  Aggravated Assault  \
# 10           5.0      2022                  47
# 18           5.0      2022                  10
# 29           5.0      2022                  24
# 50           5.0      2022                  26
# 146          5.0      2022                  61
# ...          ...       ...                 ...
# 2319         5.0      2022                  95
# 2369         5.0      2022                  57
# 2395         5.0      2022                  39
# 2408         5.0      2022                  71
# 2419         5.0      2022                   0
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 10                                    151      8        14
# 18                                     37      4         5
# 29                                     33      1        18
# 50                                    168      0        17
# 146                                   308      8        10
# ...                                   ...    ...       ...
# 2319                                  213      5        23
# 2369                                   96      3         8
# 2395                                  257      1        13
# 2408                                  771     12        15
# 2419                                   16      0         4
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 10                                      0                  71
# 18                                      0                   6
# 29                                      0                  11
# 50                                      0                  28
# 146                                     0                 276
# ...                                   ...                 ...
# 2319                                    0                  24
# 2369                                    0                   6
# 2395                                    0                  70
# 2408                                    0                  95
# 2419                                    0                   5
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 10                            115                                   80  ...
# 18                             39                                    7  ...
# 29                             18                                   29  ...
# 50                             62                                   48  ...
# 146                            40                                   23  ...
# ...                           ...                                  ...  ...
# 2319                          245                                  139  ...
# 2369                           35                                   97  ...
# 2395                           81                                   55  ...
# 2408                          182                                  144  ...
# 2419                           11                                   11  ...
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 10           38                                   30
# 18            5                                    6
# 29            7                                   25
# 50           22                                   16
# 146          39                                   18
# ...         ...                                  ...
# 2319         34                                   50
# 2369         22                                   37
# 2395         23                                   17
# 2408         50                                   39
# 2419          3                                    4
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 10                                                    7
# 18                                                    1
# 29                                                    0
# 50                                                    1
# 146                                                   0
# ...                                                 ...
# 2319                                                  2
# 2369                                                  0
# 2395                                                  2
# 2408                                                  1
# 2419                                                  0
#
#       ori_number                    AGENCY_NAME  agency_id  \
# 10     CA0010100      Alameda Police Department        938
# 18     CA0010200       Albany Police Department        939
# 29     CA0010400   Emeryville Police Department        941
# 50     CA0010800       Newark Police Department        945
# 146    CA0040400     Oroville Police Department        979
# ...          ...                            ...        ...
# 2319   CA0540600       Tulare Police Department       1773
# 2369   CA0560600  Santa Paula Police Department       1791
# 2395   CA0570100        Davis Police Department       1807
# 2408   CA0570300     Woodland Police Department       1809
# 2419   CA0579700     UC Davis Police Department       1813
#
#            agency_type_name  county_name   latitude   longitude
# 10                     City      ALAMEDA  37.766888 -122.242730
# 18                     City      ALAMEDA  37.887703 -122.298250
# 29                     City      ALAMEDA  37.648134 -121.913291
# 50                     City      ALAMEDA  37.536236 -122.029510
# 146                    City        BUTTE  39.508167 -121.554825
# ...                     ...          ...        ...         ...
# 2319                   City       TULARE  36.207127 -119.343150
# 2369                   City      VENTURA  34.356910 -119.061360
# 2395                   City         YOLO  38.679595 -121.902444
# 2408                   City         YOLO  38.679595 -121.902444
# 2419  University or College         YOLO  38.679595 -121.902444
#
# [143 rows x 40 columns]

# %%
#isolate the agencies with data for all years
agencies_all_years = all_years_included["AGENCY_NAME"].values
agencies_all_years
# Out:
# array(['Alameda Police Department', 'Albany Police Department',
#        'Emeryville Police Department', 'Newark Police Department',
#        'Oroville Police Department',
#        "Calaveras County Sheriff's Department",
#        'Williams Police Department', 'Antioch Police Department',
#        'Clayton Police Department', 'Concord Police Department',
#        'El Cerrito Police Department', 'Richmond Police Department',
#        'Moraga Police Department',
#        "El Dorado County Sheriff's Department",
#        'Placerville Police Department', 'Fresno Police Department',
#        "Glenn County Sheriff's Department", 'Ferndale Police Department',
#        'Fortuna Police Department', 'Rio Dell Police Department',
#        'Delano Police Department', 'Ridgecrest Police Department',
#        "Kings County Sheriff's Department", 'Corcoran Police Department',
#        'Hanford Police Department', 'Lemoore Police Department',
#        "Lake County Sheriff's Department", 'Lakeport Police Department',
#        "Lassen County Sheriff's Department",
#        'Susanville Police Department', 'Alhambra Police Department',
#        'Arcadia Police Department', 'Baldwin Park Police Department',
#        'Burbank Police Department', 'Covina Police Department',
#        'Culver City Police Department', 'El Monte Police Department',
#        'El Segundo Police Department', 'Gardena Police Department',
#        'Hermosa Beach Police Department', 'Irwindale Police Department',
#        'La Verne Police Department', 'Monrovia Police Department',
#        'Palos Verdes Estates Police Department',
#        'Torrance Police Department', 'Vernon Police Department',
#        'West Covina Police Department',
#        'CSU Long Beach Police Department',
#        "Madera County Sheriff's Department", 'Madera Police Department',
#        'Novato Police Department', 'San Rafael Police Department',
#        "Mariposa County Sheriff's Department",
#        'Fort Bragg Police Department', 'Gustine Police Department',
#        'Livingston Police Department',
#        "Modoc County Sheriff's Department",
#        "Monterey County Sheriff's Department", 'Carmel Police Department',
#        'Del Rey Oaks Police Department', 'Gonzales Police Department',
#        'Greenfield Police Department', 'Pacific Grove Police Department',
#        'Sand City Police Department', 'Seaside Police Department',
#        'Soledad Police Department', 'Marina Police Department',
#        'CSU Monterey Bay Police Department',
#        'Grass Valley Police Department',
#        "Orange County Sheriff's Department", 'Anaheim Police Department',
#        'Brea Police Department', 'La Palma Police Department',
#        'Garden Grove Police Department', 'La Habra Police Department',
#        'Placentia Police Department', 'Tustin Police Department',
#        'Auburn Police Department', 'Lincoln Police Department',
#        'Rocklin Police Department', 'Beaumont Police Department',
#        'Hemet Police Department', 'Murrieta Police Department',
#        'Elk Grove Police Department', 'CA Highway Patrol - Sacramento',
#        "San Benito County Sheriff's Department",
#        'Hollister Police Department', 'Chino Police Department',
#        'Colton Police Department', 'Fontana Police Department',
#        'Montclair Police Department', 'Redlands Police Department',
#        'Upland Police Department',
#        "San Diego County Sheriff's Department",
#        'Carlsbad Police Department', 'Chula Vista Police Department',
#        'Coronado Police Department', 'El Cajon Police Department',
#        'Escondido Police Department', 'La Mesa Police Department',
#        'National City Police Department', 'Oceanside Police Department',
#        'San Diego Police Department', 'San Diego Harbor',
#        'CSU San Marcos Police Department',
#        'UC San Francisco Police Department', 'Stockton Police Department',
#        'Tracy Police Department', 'Arroyo Grande Police Department',
#        'Grover Beach Police Department',
#        'Cal Poly San Luis Obispo Police Department',
#        'Atascadero Police Department',
#        "San Mateo County Sheriff's Department",
#        'Belmont Police Department', 'Hillsborough Police Department',
#        'Foster City Police Department', 'Santa Maria Police Department',
#        'UC Santa Barbara Police Department',
#        'Los Altos Police Department', 'Los Gatos Police Department',
#        'Monte Sereno', 'Morgan Hill Police Department',
#        'Mountain View Police Department', 'Palo Alto Police Department',
#        'Santa Clara Police Department',
#        'Sunnyvale Department of Public Safety',
#        'San Jose State University Police Department',
#        "Santa Cruz County Sheriff's Department",
#        'Scotts Valley Police Department',
#        'UC Santa Cruz Police Department', 'Dixon Police Department',
#        'Healdsburg Police Department', 'Yuba City Police Department',
#        "Tehama County Sheriff's Department", 'Corning Police Department',
#        'Red Bluff Police Department', 'Dinuba Police Department',
#        'Porterville Police Department', 'Tulare Police Department',
#        'Santa Paula Police Department', 'Davis Police Department',
#        'Woodland Police Department', 'UC Davis Police Department'],
#       dtype=object)

# %%
#creates a dataframe with only agencies that have the full 6 years of data

agencies_with_all_years = california_crime_counties[california_crime_counties["AGENCY_NAME"].isin(agencies_all_years)]
# Out:
#       Unnamed: 0 data_year  Aggravated Assault  \
# 5            0.0      2017                  97
# 6            1.0      2018                 109
# 7            2.0      2019                  90
# 8            3.0      2020                  87
# 9            4.0      2021                   2
# ...          ...       ...                 ...
# 2415         1.0      2018                   4
# 2416         2.0      2019                   0
# 2417         3.0      2020                   0
# 2418         4.0      2021                   1
# 2419         5.0      2022                   0
#
#       All Other Offenses (Except Traffic)  Arson  Burglary  \
# 5                                     273      4        29
# 6                                     250      0        45
# 7                                     293      3        32
# 8                                     182      5        22
# 9                                      28      0         1
# ...                                   ...    ...       ...
# 2415                                   20      0         0
# 2416                                   16      1        10
# 2417                                    8      0         2
# 2418                                    3      0         0
# 2419                                   16      0         4
#
#       Curfew and Loitering Law Violations  Disorderly Conduct  \
# 5                                       0                   2
# 6                                       0                   5
# 7                                       0                   4
# 8                                       0                   3
# 9                                       0                  16
# ...                                   ...                 ...
# 2415                                    0                   6
# 2416                                    0                  10
# 2417                                    0                   3
# 2418                                    0                   0
# 2419                                    0                   5
#
#       Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 5                             114                                  110  ...
# 6                              87                                  200  ...
# 7                             121                                  317  ...
# 8                              69                                  144  ...
# 9                              32                                    7  ...
# ...                           ...                                  ...  ...
# 2415                            6                                    8  ...
# 2416                            8                                   10  ...
# 2417                            1                                    9  ...
# 2418                            0                                    1  ...
# 2419                           11                                   11  ...
#
#       Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 5             6                                   18
# 6            14                                   28
# 7            17                                   31
# 8            22                                   12
# 9             1                                    3
# ...         ...                                  ...
# 2415          0                                    3
# 2416          3                                    2
# 2417          0                                    1
# 2418          0                                    0
# 2419          3                                    4
#
#       Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 5                                                    13
# 6                                                    12
# 7                                                    12
# 8                                                    17
# 9                                                     3
# ...                                                 ...
# 2415                                                  0
# 2416                                                  1
# 2417                                                  1
# 2418                                                  0
# 2419                                                  0
#
#       ori_number                 AGENCY_NAME  agency_id  \
# 5      CA0010100   Alameda Police Department        938
# 6      CA0010100   Alameda Police Department        938
# 7      CA0010100   Alameda Police Department        938
# 8      CA0010100   Alameda Police Department        938
# 9      CA0010100   Alameda Police Department        938
# ...          ...                         ...        ...
# 2415   CA0579700  UC Davis Police Department       1813
# 2416   CA0579700  UC Davis Police Department       1813
# 2417   CA0579700  UC Davis Police Department       1813
# 2418   CA0579700  UC Davis Police Department       1813
# 2419   CA0579700  UC Davis Police Department       1813
#
#            agency_type_name  county_name   latitude   longitude
# 5                      City      ALAMEDA  37.766888 -122.242730
# 6                      City      ALAMEDA  37.766888 -122.242730
# 7                      City      ALAMEDA  37.766888 -122.242730
# 8                      City      ALAMEDA  37.766888 -122.242730
# 9                      City      ALAMEDA  37.766888 -122.242730
# ...                     ...          ...        ...         ...
# 2415  University or College         YOLO  38.679595 -121.902444
# 2416  University or College         YOLO  38.679595 -121.902444
# 2417  University or College         YOLO  38.679595 -121.902444
# 2418  University or College         YOLO  38.679595 -121.902444
# 2419  University or College         YOLO  38.679595 -121.902444
#
# [858 rows x 40 columns]

# %%
#This dataframe aggregates information at the county level for every year in the data

county_level_data = agencies_with_all_years.groupby(['county_name','data_year']).agg({
    'Aggravated Assault': 'sum',
             'All Other Offenses (Except Traffic)': 'sum',
             'Arson': 'sum',
             'Burglary': 'sum',
             'Curfew and Loitering Law Violations': 'sum',
             'Disorderly Conduct': 'sum',
             'Driving Under the Influence': 'sum',
             'Drug Abuse Violations - Grand Total': 'sum',
             'Drunkenness': 'sum',
             'Embezzlement': 'sum',
             'Forgery and Counterfeiting': 'sum',
             'Fraud': 'sum',
             'Gambling - Total': 'sum',
             'Human Trafficking - Commercial Sex Acts': 'sum',
             'Human Trafficking - Involuntary Servitude': 'sum',
             'Larceny - Theft': 'sum',
             'Liquor Laws': 'sum',
             'Manslaughter by Negligence': 'sum',
             'Motor Vehicle Theft': 'sum',
             'Murder and Nonnegligent Manslaughter': 'sum',
             'Offenses Against the Family and Children': 'sum',
             'Prostitution and Commercialized Vice': 'sum',
             'Rape': 'sum',
             'Robbery': 'sum',
             'Simple Assault': 'sum',
             'Stolen Property: Buying, Receiving, Possessing': 'sum',
             'Suspicion': 'sum',
             'Vagrancy': 'sum',
             'Vandalism': 'sum',
             'Weapons: Carrying, Possessing, Etc.': 'sum',
             'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)': 'sum'
})
#adds a count for the number of agencies represented in each year at the county level
#county_level_data['agency_count'] = agencies_with_all_years.groupby('county_name')['AGENCY_NAME'].nunique()

county_level_data
# Out:
#                        Aggravated Assault  \
# county_name data_year
# ALAMEDA     2017                      196
#             2018                      196
#             2019                      190
#             2020                      173
#             2021                       21
# ...                                   ...
# YOLO        2018                      181
#             2019                      195
#             2020                      173
#             2021                       40
#             2022                      110
#
#                        All Other Offenses (Except Traffic)  Arson  Burglary  \
# county_name data_year
# ALAMEDA     2017                                       666      6       105
#             2018                                       568      3       103
#             2019                                       622      8        83
#             2020                                       390      6        68
#             2021                                       136      1        12
# ...                                                    ...    ...       ...
# YOLO        2018                                       848     13       105
#             2019                                       792     14       113
#             2020                                       534     13        89
#             2021                                       233      2         7
#             2022                                      1044     13        32
#
#                        Curfew and Loitering Law Violations  \
# county_name data_year
# ALAMEDA     2017                                         0
#             2018                                         0
#             2019                                         0
#             2020                                         0
#             2021                                         0
# ...                                                    ...
# YOLO        2018                                         1
#             2019                                         1
#             2020                                         0
#             2021                                         0
#             2022                                         0
#
#                        Disorderly Conduct  Driving Under the Influence  \
# county_name data_year
# ALAMEDA     2017                        5                          302
#             2018                       15                          308
#             2019                       12                          337
#             2020                        4                          193
#             2021                       33                          100
# ...                                   ...                          ...
# YOLO        2018                       11                          182
#             2019                       13                          169
#             2020                        7                          122
#             2021                       44                           61
#             2022                      170                          274
#
#                        Drug Abuse Violations - Grand Total  Drunkenness  \
# county_name data_year
# ALAMEDA     2017                                       514          301
#             2018                                       606          214
#             2019                                       649           59
#             2020                                       402           26
#             2021                                        48            0
# ...                                                    ...          ...
# YOLO        2018                                       542          269
#             2019                                       571          280
#             2020                                       372          113
#             2021                                        38            0
#             2022                                       210            0
#
#                        Embezzlement  ...  \
# county_name data_year                ...
# ALAMEDA     2017                  6  ...
#             2018                  8  ...
#             2019                 11  ...
#             2020                  2  ...
#             2021                  1  ...
# ...                             ...  ...
# YOLO        2018                  4  ...
#             2019                  3  ...
#             2020                  3  ...
#             2021                  3  ...
#             2022                  0  ...
#
#                        Prostitution and Commercialized Vice  Rape  Robbery  \
# county_name data_year
# ALAMEDA     2017                                         27    10      109
#             2018                                         20     5       84
#             2019                                          1     9       55
#             2020                                          1     1       38
#             2021                                          0     2       14
# ...                                                     ...   ...      ...
# YOLO        2018                                          0     8       50
#             2019                                          0     4       28
#             2020                                          0     4       32
#             2021                                          0     1       10
#             2022                                          1     2       24
#
#                        Simple Assault  \
# county_name data_year
# ALAMEDA     2017                  283
#             2018                  327
#             2019                  379
#             2020                  259
#             2021                   78
# ...                               ...
# YOLO        2018                  255
#             2019                  200
#             2020                  220
#             2021                   44
#             2022                  216
#
#                        Stolen Property: Buying, Receiving, Possessing  \
# county_name data_year
# ALAMEDA     2017                                                   48
#             2018                                                   29
#             2019                                                   49
#             2020                                                   45
#             2021                                                   32
# ...                                                               ...
# YOLO        2018                                                   22
#             2019                                                   23
#             2020                                                   25
#             2021                                                    8
#             2022                                                   38
#
#                        Suspicion  Vagrancy  Vandalism  \
# county_name data_year
# ALAMEDA     2017               0         5         37
#             2018               0        15         51
#             2019               0         4         50
#             2020               0         7         55
#             2021               0         2         18
# ...                          ...       ...        ...
# YOLO        2018               0        18         35
#             2019               0        21         53
#             2020               0        29         54
#             2021               0         0         14
#             2022               0        10         76
#
#                        Weapons: Carrying, Possessing, Etc.  \
# county_name data_year
# ALAMEDA     2017                                        64
#             2018                                        63
#             2019                                        77
#             2020                                        74
#             2021                                        29
# ...                                                    ...
# YOLO        2018                                        42
#             2019                                        25
#             2020                                        31
#             2021                                        11
#             2022                                        60
#
#                        Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)
# county_name data_year
# ALAMEDA     2017                                                      24
#             2018                                                      22
#             2019                                                      21
#             2020                                                      24
#             2021                                                       3
# ...                                                                  ...
# YOLO        2018                                                      24
#             2019                                                      21
#             2020                                                      20
#             2021                                                       1
#             2022                                                       3
#
# [258 rows x 31 columns]

# %%
# Calculate the count of unique agencies for each county and year
unique_agency_count = agencies_with_all_years.groupby(['county_name', 'data_year'])['AGENCY_NAME'].nunique().reset_index()

# Merge the unique agency count with county_level_data
county_level_data = county_level_data.merge(unique_agency_count, on=['county_name', 'data_year'], how='left')
county_level_data.rename(columns={'AGENCY_NAME': 'agency_count'}, inplace=True)

# %%
#create a csv for the county level dataframe

county_level_data.to_csv('Output/county_level_crime_data.csv')

# %%
#agency level
agency_level_data = agencies_with_all_years.groupby(['AGENCY_NAME','data_year']).agg({
    'Aggravated Assault': 'sum',
             'All Other Offenses (Except Traffic)': 'sum',
             'Arson': 'sum',
             'Burglary': 'sum',
             'Curfew and Loitering Law Violations': 'sum',
             'Disorderly Conduct': 'sum',
             'Driving Under the Influence': 'sum',
             'Drug Abuse Violations - Grand Total': 'sum',
             'Drunkenness': 'sum',
             'Embezzlement': 'sum',
             'Forgery and Counterfeiting': 'sum',
             'Fraud': 'sum',
             'Gambling - Total': 'sum',
             'Human Trafficking - Commercial Sex Acts': 'sum',
             'Human Trafficking - Involuntary Servitude': 'sum',
             'Larceny - Theft': 'sum',
             'Liquor Laws': 'sum',
             'Manslaughter by Negligence': 'sum',
             'Motor Vehicle Theft': 'sum',
             'Murder and Nonnegligent Manslaughter': 'sum',
             'Offenses Against the Family and Children': 'sum',
             'Prostitution and Commercialized Vice': 'sum',
             'Rape': 'sum',
             'Robbery': 'sum',
             'Simple Assault': 'sum',
             'Stolen Property: Buying, Receiving, Possessing': 'sum',
             'Suspicion': 'sum',
             'Vagrancy': 'sum',
             'Vandalism': 'sum',
             'Weapons: Carrying, Possessing, Etc.': 'sum',
             'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)': 'sum'
})
agency_level_data
# Out:
#                                        Aggravated Assault  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                       97
#                             2018                      109
#                             2019                       90
#                             2020                       87
#                             2021                        2
# ...                                                   ...
# Yuba City Police Department 2018                      245
#                             2019                      250
#                             2020                      228
#                             2021                        7
#                             2022                      125
#
#                                        All Other Offenses (Except Traffic)  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                       273
#                             2018                                       250
#                             2019                                       293
#                             2020                                       182
#                             2021                                        28
# ...                                                                    ...
# Yuba City Police Department 2018                                       959
#                             2019                                       943
#                             2020                                       623
#                             2021                                        87
#                             2022                                       860
#
#                                        Arson  Burglary  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017           4        29
#                             2018           0        45
#                             2019           3        32
#                             2020           5        22
#                             2021           0         1
# ...                                      ...       ...
# Yuba City Police Department 2018           3        81
#                             2019           6       102
#                             2020           4        83
#                             2021           0         6
#                             2022           2        34
#
#                                        Curfew and Loitering Law Violations  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                         0
#                             2018                                         0
#                             2019                                         0
#                             2020                                         0
#                             2021                                         0
# ...                                                                    ...
# Yuba City Police Department 2018                                         4
#                             2019                                         0
#                             2020                                         6
#                             2021                                         0
#                             2022                                         0
#
#                                        Disorderly Conduct  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                        2
#                             2018                        5
#                             2019                        4
#                             2020                        3
#                             2021                       16
# ...                                                   ...
# Yuba City Police Department 2018                        8
#                             2019                        8
#                             2020                        7
#                             2021                       15
#                             2022                      279
#
#                                        Driving Under the Influence  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                               114
#                             2018                                87
#                             2019                               121
#                             2020                                69
#                             2021                                32
# ...                                                            ...
# Yuba City Police Department 2018                               257
#                             2019                               241
#                             2020                               174
#                             2021                                17
#                             2022                               193
#
#                                        Drug Abuse Violations - Grand Total  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                       110
#                             2018                                       200
#                             2019                                       317
#                             2020                                       144
#                             2021                                         7
# ...                                                                    ...
# Yuba City Police Department 2018                                       540
#                             2019                                       635
#                             2020                                       365
#                             2021                                        27
#                             2022                                       331
#
#                                        Drunkenness  Embezzlement  ...  \
# AGENCY_NAME                 data_year                             ...
# Alameda Police Department   2017               201             2  ...
#                             2018               130             0  ...
#                             2019                 2             5  ...
#                             2020                 0             1  ...
#                             2021                 0             1  ...
# ...                                            ...           ...  ...
# Yuba City Police Department 2018               366             3  ...
#                             2019               369             4  ...
#                             2020               158             2  ...
#                             2021                 0             0  ...
#                             2022                 0             0  ...
#
#                                        Prostitution and Commercialized Vice  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                         27
#                             2018                                         20
#                             2019                                          0
#                             2020                                          0
#                             2021                                          0
# ...                                                                     ...
# Yuba City Police Department 2018                                          0
#                             2019                                          0
#                             2020                                          0
#                             2021                                          0
#                             2022                                          0
#
#                                        Rape  Robbery  Simple Assault  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017          8       49             118
#                             2018          3       23             131
#                             2019          1       18             197
#                             2020          1       14             160
#                             2021          2        5              19
# ...                                     ...      ...             ...
# Yuba City Police Department 2018         10       28             209
#                             2019          6       25             232
#                             2020          8       37             162
#                             2021          1        2              12
#                             2022          4       29             225
#
#                                        Stolen Property: Buying, Receiving, Possessing  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                                    8
#                             2018                                                    1
#                             2019                                                    6
#                             2020                                                    5
#                             2021                                                    3
# ...                                                                               ...
# Yuba City Police Department 2018                                                   43
#                             2019                                                   54
#                             2020                                                   35
#                             2021                                                    9
#                             2022                                                   39
#
#                                        Suspicion  Vagrancy  Vandalism  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017               0         2          6
#                             2018               0         1         14
#                             2019               0         0         17
#                             2020               0         0         22
#                             2021               0         0          1
# ...                                          ...       ...        ...
# Yuba City Police Department 2018               0        20         32
#                             2019               0        12         31
#                             2020               0         6         43
#                             2021               0         0         10
#                             2022               0        10         34
#
#                                        Weapons: Carrying, Possessing, Etc.  \
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                        18
#                             2018                                        28
#                             2019                                        31
#                             2020                                        12
#                             2021                                         3
# ...                                                                    ...
# Yuba City Police Department 2018                                        73
#                             2019                                        69
#                             2020                                        43
#                             2021                                         1
#                             2022                                        28
#
#                                        Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)
# AGENCY_NAME                 data_year
# Alameda Police Department   2017                                                      13
#                             2018                                                      12
#                             2019                                                      12
#                             2020                                                      17
#                             2021                                                       3
# ...                                                                                  ...
# Yuba City Police Department 2018                                                      16
#                             2019                                                      16
#                             2020                                                      18
#                             2021                                                       0
#                             2022                                                       4
#
# [858 rows x 31 columns]

# %%
#create a csv for the agency level dataframe

agency_level_data.to_csv('Output/agency_level_crime_data.csv')

# %%
#putting these categories into new columns in the dataframe

#copy the dataframe
consolidated_crime_df = agencies_with_all_years.copy()

#these are the crimes that should be mapped to the crimes against persons category
consolidated_crime_df["Crimes Against Persons"] = consolidated_crime_df["Aggravated Assault"] + consolidated_crime_df["Human Trafficking - Commercial Sex Acts"] + consolidated_crime_df["Human Trafficking - Involuntary Servitude"] + consolidated_crime_df["Manslaughter by Negligence"] + consolidated_crime_df["Murder and Nonnegligent Manslaughter"] + consolidated_crime_df["Rape"] + consolidated_crime_df["Simple Assault"] + consolidated_crime_df["Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)"]

#these are the crimes that should be mapped to the crimes against society category
consolidated_crime_df["Crimes Against Society"] = consolidated_crime_df["Curfew and Loitering Law Violations"] + consolidated_crime_df["Disorderly Conduct"] + consolidated_crime_df["Driving Under the Influence"] + consolidated_crime_df["Drug Abuse Violations - Grand Total"] + consolidated_crime_df["Drunkenness"] + consolidated_crime_df["Gambling - Total"] + consolidated_crime_df["Liquor Laws"] + consolidated_crime_df["Offenses Against the Family and Children"] + consolidated_crime_df["Prostitution and Commercialized Vice"]+ consolidated_crime_df["Vagrancy"]

#these are the crimes that should be mapped to the crimes against property category
consolidated_crime_df["Crimes Against Property"] = consolidated_crime_df["Arson"] + consolidated_crime_df["Burglary"] + consolidated_crime_df["Embezzlement"] + consolidated_crime_df["Forgery and Counterfeiting"] + consolidated_crime_df["Fraud"] + consolidated_crime_df["Larceny - Theft"] + consolidated_crime_df["Motor Vehicle Theft"] + consolidated_crime_df["Robbery"]+ consolidated_crime_df["Stolen Property: Buying, Receiving, Possessing"] + consolidated_crime_df["Vandalism"]+ consolidated_crime_df["Weapons: Carrying, Possessing, Etc."]

#del consolidated_crime_df["Crimes Against Property"]

#create a list of columns to remove
columns_to_drop = [
    'Unnamed: 0','Aggravated Assault', 'Arson', 'Burglary',
       'Curfew and Loitering Law Violations', 'Disorderly Conduct',
       'Driving Under the Influence', 'Drug Abuse Violations - Grand Total',
       'Drunkenness', 'Embezzlement', 'Forgery and Counterfeiting', 'Fraud',
       'Gambling - Total', 'Human Trafficking - Commercial Sex Acts',
       'Human Trafficking - Involuntary Servitude', 'Larceny - Theft',
       'Liquor Laws', 'Manslaughter by Negligence', 'Motor Vehicle Theft',
       'Murder and Nonnegligent Manslaughter',
       'Offenses Against the Family and Children',
       'Prostitution and Commercialized Vice', 'Rape', 'Robbery',
       'Simple Assault', 'Stolen Property: Buying, Receiving, Possessing', 'Vagrancy', 'Vandalism',
       'Weapons: Carrying, Possessing, Etc.',
       'Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)' 
]
#deletes columns we no longer need
consolidated_crime_df.drop(columns=columns_to_drop, inplace=True)
consolidated_crime_df
# Out:
#      data_year  All Other Offenses (Except Traffic)  Suspicion ori_number  \
# 5         2017                                  273          0  CA0010100
# 6         2018                                  250          0  CA0010100
# 7         2019                                  293          0  CA0010100
# 8         2020                                  182          0  CA0010100
# 9         2021                                   28          0  CA0010100
# ...        ...                                  ...        ...        ...
# 2415      2018                                   20          0  CA0579700
# 2416      2019                                   16          0  CA0579700
# 2417      2020                                    8          0  CA0579700
# 2418      2021                                    3          0  CA0579700
# 2419      2022                                   16          0  CA0579700
#
#                      AGENCY_NAME agency_id       agency_type_name county_name  \
# 5      Alameda Police Department       938                   City     ALAMEDA
# 6      Alameda Police Department       938                   City     ALAMEDA
# 7      Alameda Police Department       938                   City     ALAMEDA
# 8      Alameda Police Department       938                   City     ALAMEDA
# 9      Alameda Police Department       938                   City     ALAMEDA
# ...                          ...       ...                    ...         ...
# 2415  UC Davis Police Department      1813  University or College        YOLO
# 2416  UC Davis Police Department      1813  University or College        YOLO
# 2417  UC Davis Police Department      1813  University or College        YOLO
# 2418  UC Davis Police Department      1813  University or College        YOLO
# 2419  UC Davis Police Department      1813  University or College        YOLO
#
#        latitude   longitude  Crimes Against Persons  Crimes Against Society  \
# 5     37.766888 -122.242730                     236                     457
# 6     37.766888 -122.242730                     257                     445
# 7     37.766888 -122.242730                     300                     445
# 8     37.766888 -122.242730                     266                     217
# 9     37.766888 -122.242730                      27                      55
# ...         ...         ...                     ...                     ...
# 2415  38.679595 -121.902444                      17                      27
# 2416  38.679595 -121.902444                       9                      34
# 2417  38.679595 -121.902444                       8                      13
# 2418  38.679595 -121.902444                       1                       1
# 2419  38.679595 -121.902444                       5                      27
#
#       Crimes Against Property
# 5                         231
# 6                         211
# 7                         223
# 8                         178
# 9                          30
# ...                       ...
# 2415                       13
# 2416                       25
# 2417                        7
# 2418                        0
# 2419                       20
#
# [858 rows x 13 columns]

# %%
#creates a list of new column order
new_order = ["data_year",
             "county_name",
             "AGENCY_NAME",
             "agency_id",
             "Crimes Against Persons",
             "Crimes Against Society",
             "Crimes Against Property",
             "All Other Offenses (Except Traffic)",
             "Suspicion",
             "latitude",
             "longitude",
             "ori_number",
             "agency_type_name",
            ]
#changes the order of the dataframe
consolidated_crime_df = consolidated_crime_df.reindex(columns=new_order)
consolidated_crime_df
# Out:
#      data_year county_name                 AGENCY_NAME agency_id  \
# 5         2017     ALAMEDA   Alameda Police Department       938
# 6         2018     ALAMEDA   Alameda Police Department       938
# 7         2019     ALAMEDA   Alameda Police Department       938
# 8         2020     ALAMEDA   Alameda Police Department       938
# 9         2021     ALAMEDA   Alameda Police Department       938
# ...        ...         ...                         ...       ...
# 2415      2018        YOLO  UC Davis Police Department      1813
# 2416      2019        YOLO  UC Davis Police Department      1813
# 2417      2020        YOLO  UC Davis Police Department      1813
# 2418      2021        YOLO  UC Davis Police Department      1813
# 2419      2022        YOLO  UC Davis Police Department      1813
#
#       Crimes Against Persons  Crimes Against Society  Crimes Against Property  \
# 5                        236                     457                      231
# 6                        257                     445                      211
# 7                        300                     445                      223
# 8                        266                     217                      178
# 9                         27                      55                       30
# ...                      ...                     ...                      ...
# 2415                      17                      27                       13
# 2416                       9                      34                       25
# 2417                       8                      13                        7
# 2418                       1                       1                        0
# 2419                       5                      27                       20
#
#       All Other Offenses (Except Traffic)  Suspicion   latitude   longitude  \
# 5                                     273          0  37.766888 -122.242730
# 6                                     250          0  37.766888 -122.242730
# 7                                     293          0  37.766888 -122.242730
# 8                                     182          0  37.766888 -122.242730
# 9                                      28          0  37.766888 -122.242730
# ...                                   ...        ...        ...         ...
# 2415                                   20          0  38.679595 -121.902444
# 2416                                   16          0  38.679595 -121.902444
# 2417                                    8          0  38.679595 -121.902444
# 2418                                    3          0  38.679595 -121.902444
# 2419                                   16          0  38.679595 -121.902444
#
#      ori_number       agency_type_name
# 5     CA0010100                   City
# 6     CA0010100                   City
# 7     CA0010100                   City
# 8     CA0010100                   City
# 9     CA0010100                   City
# ...         ...                    ...
# 2415  CA0579700  University or College
# 2416  CA0579700  University or College
# 2417  CA0579700  University or College
# 2418  CA0579700  University or College
# 2419  CA0579700  University or College
#
# [858 rows x 13 columns]

# %%
#creates a dataframe grouped by county for the consolidated categories
county_level_data_consolidated = consolidated_crime_df.groupby(['county_name','data_year']).agg({
    'Crimes Against Persons': 'sum',
             'Crimes Against Society': 'sum',
             'Crimes Against Property': 'sum',
})

# %%
# Calculate the count of unique agencies for each county and year
unique_agency_count_consolidated = agencies_with_all_years.groupby(['county_name', 'data_year'])['AGENCY_NAME'].nunique().reset_index()

# Merge the unique agency count with county_level_data
county_level_data_consolidated = county_level_data_consolidated.merge(unique_agency_count_consolidated, on=['county_name', 'data_year'], how='left')
county_level_data_consolidated.rename(columns={'AGENCY_NAME': 'agency_count'}, inplace=True)

county_level_data_consolidated
# Out:
#     county_name data_year  Crimes Against Persons  Crimes Against Society  \
# 0       ALAMEDA      2017                     517                    1157
# 1       ALAMEDA      2018                     556                    1182
# 2       ALAMEDA      2019                     600                    1063
# 3       ALAMEDA      2020                     458                     634
# 4       ALAMEDA      2021                     105                     183
# ..          ...       ...                     ...                     ...
# 253        YOLO      2018                     472                    1033
# 254        YOLO      2019                     422                    1059
# 255        YOLO      2020                     419                     644
# 256        YOLO      2021                      86                     143
# 257        YOLO      2022                     331                     667
#
#      Crimes Against Property  agency_count
# 0                        972             4
# 1                        889             4
# 2                        781             4
# 3                        578             4
# 4                        278             4
# ..                       ...           ...
# 253                      450             3
# 254                      417             3
# 255                      379             3
# 256                       89             3
# 257                      370             3
#
# [258 rows x 6 columns]

# %%
#creates a csv with the dataframe
county_level_data_consolidated.to_csv('Output/county_level_crime_data_consolidated.csv')

# %%
#creates a dataframe grouped by agency for the consolidated categories
agency_level_data_consolidated = consolidated_crime_df.groupby(['AGENCY_NAME','data_year']).agg({
    'Crimes Against Persons': 'sum',
             'Crimes Against Society': 'sum',
             'Crimes Against Property': 'sum',
})

#creates a csv with the dataframe
agency_level_data_consolidated.to_csv('Output/agency_level_crime_data_consolidated.csv')

# %%
#reads in file with excel method
file_path = 'poverty_population_county.csv'

poverty_data = pd.read_csv(file_path)
# Out:
#   COUNTY_NAME  POVERTY_RATE POPULATION
# 0    Alameda           12.0  1,487,888
# 1     Alpine           13.7      1,160
# 2     Amador           10.5     33,228
# 3      Butte           20.6    214,624
# 4  Calaveras           10.4     44,740

# %%
#change case of the county column to fit with the existing data sets
poverty_data['COUNTY_NAME'] = poverty_data['COUNTY_NAME'].str.upper()
# Out:
#   COUNTY_NAME  POVERTY_RATE POPULATION
# 0    ALAMEDA           12.0  1,487,888
# 1     ALPINE           13.7      1,160
# 2     AMADOR           10.5     33,228
# 3      BUTTE           20.6    214,624
# 4  CALAVERAS           10.4     44,740

# %%
#change the case of the county name column to match our existing dataframe
poverty_data = poverty_data.rename(columns={'COUNTY_NAME':'county_name'})
poverty_data.head()
# Out:
#   county_name  POVERTY_RATE POPULATION
# 0    ALAMEDA           12.0  1,487,888
# 1     ALPINE           13.7      1,160
# 2     AMADOR           10.5     33,228
# 3      BUTTE           20.6    214,624
# 4  CALAVERAS           10.4     44,740

# %%
#merging the consolidated dataframe
consolidated_crime_full_counties.reset_index(inplace=True)
population_consol_df = pd.merge(consolidated_crime_full_counties, poverty_data, on='county_name', how = 'outer')
population_consol_df
#consolidated_crime_full_counties.head()
# Out:
#      index county_name data_year  Crimes Against Persons  \
# 0      0.0     ALAMEDA      2017                  7284.0
# 1      1.0     ALAMEDA      2018                  7242.0
# 2      2.0     ALAMEDA      2019                  7188.0
# 3      3.0     ALAMEDA      2020                  6301.0
# 4      4.0     ALAMEDA      2021                   105.0
# ..     ...         ...       ...                     ...
# 386    NaN     TULARE        NaN                     NaN
# 387    NaN   TUOLUMNE        NaN                     NaN
# 388    NaN    VENTURA        NaN                     NaN
# 389    NaN       YOLO        NaN                     NaN
# 390    NaN       YUBA        NaN                     NaN
#
#      Crimes Against Society  Crimes Against Property  POVERTY_RATE POPULATION
# 0                   12156.0                   8169.0           NaN        NaN
# 1                   11225.0                   7670.0           NaN        NaN
# 2                   10867.0                   7321.0           NaN        NaN
# 3                    6507.0                   6477.0           NaN        NaN
# 4                     183.0                    278.0           NaN        NaN
# ..                      ...                      ...           ...        ...
# 386                     NaN                      NaN          24.8    435,395
# 387                     NaN                      NaN          13.1     51,217
# 388                     NaN                      NaN          10.3    811,132
# 389                     NaN                      NaN          18.7    193,063
# 390                     NaN                      NaN          20.6     70,740
#
# [391 rows x 8 columns]

# %%
column1 = poverty_data['county_name']
column2 = consolidated_crime_full_counties['county_name']

matching = column1.equals(column2)
print(matching)

# Find the indices where the values don't match
# mismatch_indices = column1 != column2

# Get the values that don't match
# mismatch_values_column1 = column1[mismatch_indices]
# mismatch_values_column2 = column2[mismatch_indices]

# Optionally, you can also get the corresponding indices or rows where the values don't match
# mismatch_indices = mismatch_indices[mismatch_indices]

# Display the mismatched values and their indices
# print("Mismatched values in column1:", mismatch_values_column1)
# print("Mismatched values in column2:", mismatch_values_column2)
# print("Indices of mismatched values:", mismatch_indices)

index1 = column1.index
index2 = column1.index

# Check if the index labels are not identical
labels_not_identical = not index1.equals(index2)

# Print the result
if labels_not_identical:
    print("The index labels of the two Series are not identical.")
else:
    print("The index labels of the two Series are identical.")
# Out:
# False
# The index labels of the two Series are identical.

# %%
print('county_name' in poverty_data.columns)
print('county_name' in consolidated_crime_full_counties.columns)
# Out:
# True
# True

# %%
#merge the data
population_disagg_crime_df = pd.merge(county_full, poverty_data, on='county_name', how = 'outer')

population_disagg_crime_df
# Out:
#     county_name data_year  Aggravated Assault  \
# 0       ALAMEDA      2017              2625.0
# 1       ALAMEDA      2018              2725.0
# 2       ALAMEDA      2019              2627.0
# 3       ALAMEDA      2020              2524.0
# 4       ALAMEDA      2021                21.0
# ..          ...       ...                 ...
# 386     TULARE        NaN                 NaN
# 387   TUOLUMNE        NaN                 NaN
# 388    VENTURA        NaN                 NaN
# 389       YOLO        NaN                 NaN
# 390       YUBA        NaN                 NaN
#
#      All Other Offenses (Except Traffic)  Arson  Burglary  \
# 0                                 8239.0   52.0    1082.0
# 1                                 7733.0   71.0    1014.0
# 2                                 6919.0   41.0    1087.0
# 3                                 4357.0   65.0     990.0
# 4                                  136.0    1.0      12.0
# ..                                   ...    ...       ...
# 386                                  NaN    NaN       NaN
# 387                                  NaN    NaN       NaN
# 388                                  NaN    NaN       NaN
# 389                                  NaN    NaN       NaN
# 390                                  NaN    NaN       NaN
#
#      Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                    0.0               156.0
# 1                                    0.0               157.0
# 2                                    0.0               170.0
# 3                                    0.0                89.0
# 4                                    0.0                33.0
# ..                                   ...                 ...
# 386                                  NaN                 NaN
# 387                                  NaN                 NaN
# 388                                  NaN                 NaN
# 389                                  NaN                 NaN
# 390                                  NaN                 NaN
#
#      Driving Under the Influence  Drug Abuse Violations - Grand Total  ...  \
# 0                         1905.0                               7556.0  ...
# 1                         1855.0                               7153.0  ...
# 2                         2031.0                               6910.0  ...
# 3                         1253.0                               4344.0  ...
# 4                          100.0                                 48.0  ...
# ..                           ...                                  ...  ...
# 386                          NaN                                  NaN  ...
# 387                          NaN                                  NaN  ...
# 388                          NaN                                  NaN  ...
# 389                          NaN                                  NaN  ...
# 390                          NaN                                  NaN  ...
#
#      Simple Assault  Stolen Property: Buying, Receiving, Possessing  \
# 0            4000.0                                           629.0
# 1            4013.0                                           574.0
# 2            4165.0                                           565.0
# 3            3408.0                                           690.0
# 4              78.0                                            32.0
# ..              ...                                             ...
# 386             NaN                                             NaN
# 387             NaN                                             NaN
# 388             NaN                                             NaN
# 389             NaN                                             NaN
# 390             NaN                                             NaN
#
#      Suspicion  Vagrancy  Vandalism  Weapons: Carrying, Possessing, Etc.  \
# 0          0.0      77.0      922.0                               1024.0
# 1          0.0      77.0      853.0                                946.0
# 2          0.0      58.0      765.0                                908.0
# 3          0.0      45.0      673.0                                939.0
# 4          0.0       2.0       18.0                                 29.0
# ..         ...       ...        ...                                  ...
# 386        NaN       NaN        NaN                                  NaN
# 387        NaN       NaN        NaN                                  NaN
# 388        NaN       NaN        NaN                                  NaN
# 389        NaN       NaN        NaN                                  NaN
# 390        NaN       NaN        NaN                                  NaN
#
#      Sex Offenses (Except Rape, and Prostitution and Commercialized Vice)  \
# 0                                                457.0
# 1                                                360.0
# 2                                                278.0
# 3                                                234.0
# 4                                                  3.0
# ..                                                 ...
# 386                                                NaN
# 387                                                NaN
# 388                                                NaN
# 389                                                NaN
# 390                                                NaN
#
#      agency_count  POVERTY_RATE  POPULATION
# 0            18.0           NaN         NaN
# 1            18.0           NaN         NaN
# 2            18.0           NaN         NaN
# 3            18.0           NaN         NaN
# 4             4.0           NaN         NaN
# ..            ...           ...         ...
# 386           NaN          24.8     435,395
# 387           NaN          13.1      51,217
# 388           NaN          10.3     811,132
# 389           NaN          18.7     193,063
# 390           NaN          20.6      70,740
#
# [391 rows x 36 columns]
